# %% [markdown]
# <a href="https://colab.research.google.com/github/saniyatazeen/microsoft-data-analysis-prediction-by-machine-learning-/blob/main/Microsoft_data_analysis_prediction_by_machine_learning_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/content/microsoft_stock_synthetic.csv")

# %%
try:
    msft = yf.download("MSFT", start="2023-01-01")  # Download data
    print("Data downloaded successfully.")
except Exception as e:
    print(f"Error downloading data: {e}")
    exit()  # Exit if data download fails
# Out:
# [*********************100%***********************]  1 of 1 completed
# Data downloaded successfully.

# %%
print(msft.head())
print(msft.info())
print(msft.describe())
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            MSFT        MSFT        MSFT        MSFT      MSFT
# Date
# 2023-01-03  235.711716  241.782092  233.566906  239.155204  25740000
# 2023-01-04  225.400925  229.110043  222.311624  228.529573  50623400
# 2023-01-05  218.720551  223.875950  218.179428  223.531595  39585600
# 2023-01-06  221.298248  222.114849  215.808357  219.399417  43613600
# 2023-01-09  223.452881  227.506369  222.754353  222.793701  27369800
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 531 entries, 2023-01-03 to 2025-02-13
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, MSFT)   531 non-null    float64
#  1   (High, MSFT)    531 non-null    float64
#  2   (Low, MSFT)     531 non-null    float64
#  3   (Open, MSFT)    531 non-null    float64
#  4   (Volume, MSFT)  531 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 24.9 KB
# None
# Price        Close        High         Low        Open        Volume
# Ticker        MSFT        MSFT        MSFT        MSFT          MSFT
# count   531.000000  531.000000  531.000000  531.000000  5.310000e+02
# mean    367.985519  371.054089  364.600204  367.895896  2.401741e+07
# std      62.590729   62.812749   62.296257   62.721355  9.726319e+06
# min     218.720551  222.114849  215.808357  219.399417  7.164500e+06
# 25%     323.958786  326.941610  320.539888  322.900241  1.770870e+07
# 50%     393.651093  397.655865  388.129383  392.812565  2.150220e+07
# 75%     418.870010  422.747552  415.641395  419.055687  2.701340e+07
# max     465.786438  466.573450  462.698189  465.228569  7.847820e+07

# %%
msft = data
msft['Daily Return'] = msft['Close'].pct_change()

# %%
msft['50-Day MA'] = msft['Close'].rolling(window=50).mean()
msft['200-Day MA'] = msft['Close'].rolling(window=200).mean()

# %%
plt.subplot(2, 1, 1)
plt.plot(msft['Close'], label='Adjusted Close Price')
plt.plot(msft['50-Day MA'], label='50-Day MA')
plt.plot(msft['200-Day MA'], label='200-Day MA')
plt.title('Microsoft Stock Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()

# %%
plt.subplot(2, 1, 2)
plt.plot(msft['Daily Return'], label='Daily Return')
plt.title('Microsoft Daily Returns')
plt.xlabel('Date')
plt.ylabel('Return')
plt.legend()

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.histplot(msft['Daily Return'], kde=True, bins=50) #using seaborn for better aesthetics
plt.title('Distribution of Daily Returns')
plt.xlabel('Daily Return')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(y=msft['Daily Return'])
plt.title('Box Plot of Daily Returns')
plt.ylabel('Daily Return')
plt.show()

# %%
volatility = msft['Daily Return'].std() * (252**0.5)
print(f"Annualized Volatility: {volatility:.4f}")
# Out:
# Annualized Volatility: 0.1357

# %%
risk_free_rate = 0.0
sharpe_ratio = (msft['Daily Return'].mean() * 252 - risk_free_rate) / (msft['Daily Return'].std() * (252**0.5))
print(f"Sharpe Ratio: {sharpe_ratio:.4f}")
# Out:
# Sharpe Ratio: 0.2092

# %%
plt.subplot(3, 1, 3)  # 3 rows, 1 column, plot 3
sns.lineplot(x=msft.index, y='Volume', data=msft, color='purple')
plt.title('Microsoft Trading Volume')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.grid(True, linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(y=msft['Daily Return'].dropna(), color='lightcoral')
plt.title('Violin Plot of Daily Returns')
plt.ylabel('Daily Return')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(y=msft['Daily Return'].dropna(), color='lightcoral')
plt.title('Violin Plot of Daily Returns')
plt.ylabel('Daily Return')
plt.show()

# %%
plt.figure(figsize=(10, 8))
correlation_matrix = msft[['Close', 'Volume', 'Daily Return']].corr() # Calculate correlation only for relevant columns
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
plt.subplot(3, 1, 1)  # 3 rows, 1 column, plot 1
sns.lineplot(data=msft[['Close', '50-Day MA', '200-Day MA']], palette=['blue', 'orange', 'green'])
plt.title('Microsoft Stock Price (Adj. Close) with Moving Averages')
plt.xlabel('Date')
plt.ylabel('Price')
plt.grid(True, linestyle='--', alpha=0.7)

# %%
# Plot Closing Price over Time
plt.figure(figsize=(12, 6))
sns.lineplot(x=data["Date"], y=data["Close"], label="Close Price") # Use 'data' instead of 'df'
plt.title("Closing Price Over Time")
plt.xlabel("Date")
plt.ylabel("Closing Price")
plt.xticks(rotation=45)
plt.show()

# Distribution of Closing Prices
plt.figure(figsize=(8, 5))
sns.histplot(data["Close"], bins=50, kde=True) # Use 'data' instead of 'df'
plt.title("Distribution of Closing Prices")
plt.xlabel("Closing Price")
plt.ylabel("Frequency")
plt.show()

# Scatter Plot of Volume vs. Closing Price
plt.figure(figsize=(10, 6))
sns.scatterplot(x=data["Volume"], y=data["Close"], alpha=0.5) # Use 'data' instead of 'df'
plt.title("Volume vs. Closing Price")
plt.xlabel("Volume")
plt.ylabel("Closing Price")
plt.xscale("log")  # Log scale for better visualization
plt.show()

# Pairplot for numerical columns
sns.pairplot(data[["Open", "High", "Low", "Close", "Volume"]])
plt.show()
